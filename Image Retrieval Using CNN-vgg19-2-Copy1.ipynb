# %%
def preprocess(img,input_size):
    nimg = img.convert('RGB').resize(input_size, resample= 0)
    img_arr = (np.array(nimg))
    return img_arr

def reshape(imgs_arr):
    return np.stack(imgs_arr, axis=0)

# %%
# %matplotlib inline
from keras.preprocessing import image
from keras.models import Model
from keras.layers import Input
from keras.layers import Dense, Dropout, Concatenate
from keras.layers import Flatten
from keras.layers.convolutional import Conv2D
from keras.layers.pooling import MaxPooling2D, AveragePooling2D, GlobalAveragePooling2D
from keras.layers.merge import concatenate
from PIL import Image
from keras.applications.efficientnet import EfficientNetB7
from keras.applications.vgg19 import VGG19, preprocess_input

import numpy as np
from numpy import linalg as LA
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import time


class FeatureExtractor:
    def __init__(self):
        vgg_net = VGG19(include_top=False, input_tensor=Input(shape=(128, 128, 3)))
        
        headModel2 = vgg_net.output
        headModel2 = Flatten(name="flatten2")(headModel2)
        headModel2 = Dense(8192, activation='relu')(headModel2)
        self.model = Model(inputs=vgg_net.input, outputs=headModel2)
        

    def extract_features(self, img_path):
        im = Image.open(img_path)
        X = preprocess(im,(128,128))
        X = reshape([X])
        
        feat = self.model.predict(X)
        norm_feat = feat[0]/LA.norm(feat[0])
        return norm_feat

# %%
import os
import h5py
import numpy as np
import time


'''
 Returns a list of filenames for all jpg images in a directory. 
'''
def get_imlist(path):
    return [os.path.join(path,f) for f in os.listdir(path) if f.endswith('.jpg')]


'''
 Extract features and index the images
'''
os.environ["CUDA_VISIBLE_DEVICES"] = "5"
path = 'CitraBatik_Dataset/train/' 
#path = 'C:/Users/Fadhlan/Temu Kembali Citra/Batik300/' 
img_list = get_imlist(path)

print("--------------------------------------------------")
print("         feature extraction starts")
print("--------------------------------------------------")
start = time.time()

feats = []
names = []

model = FeatureExtractor()
for i, img_path in enumerate(img_list):
    norm_feat = model.extract_features(img_path)
    img_name = os.path.split(img_path)[1]
    feats.append(norm_feat)
    names.append(img_name)
    print("extracting feature from image No. %d , %d images in total" %((i+1), len(img_list)))

feats = np.array(feats)
# Out:
# --------------------------------------------------
#          feature extraction starts
# --------------------------------------------------
# extracting feature from image No. 1 , 250 images in total
# extracting feature from image No. 2 , 250 images in total
# extracting feature from image No. 3 , 250 images in total
# extracting feature from image No. 4 , 250 images in total
# extracting feature from image No. 5 , 250 images in total
# extracting feature from image No. 6 , 250 images in total
# extracting feature from image No. 7 , 250 images in total
# extracting feature from image No. 8 , 250 images in total
# extracting feature from image No. 9 , 250 images in total
# extracting feature from image No. 10 , 250 images in total
# extracting feature from image No. 11 , 250 images in total
# extracting feature from image No. 12 , 250 images in total
# extracting feature from image No. 13 , 250 images in total
# extracting feature from image No. 14 , 250 images in total
# extracting feature from image No. 15 , 250 images in total
# extracting feature from image No. 16 , 250 images in total
# extracting feature from image No. 17 , 250 images in total
# extracting feature from image No. 18 , 250 images in total
# extracting feature from image No. 19 , 250 images in total
# extracting feature from image No. 20 , 250 images in total
# extracting feature from image No. 21 , 250 images in total
# extracting feature from image No. 22 , 250 images in total
# extracting feature from image No. 23 , 250 images in total
# extracting feature from image No. 24 , 250 images in total
# extracting feature from image No. 25 , 250 images in total
# extracting feature from image No. 26 , 250 images in total
# extracting feature from image No. 27 , 250 images in total
# extracting feature from image No. 28 , 250 images in total
# extracting feature from image No. 29 , 250 images in total
# extracting feature from image No. 30 , 250 images in total
# extracting feature from image No. 31 , 250 images in total
# extracting feature from image No. 32 , 250 images in total
# extracting feature from image No. 33 , 250 images in total
# extracting feature from image No. 34 , 250 images in total
# extracting feature from image No. 35 , 250 images in total
# extracting feature from image No. 36 , 250 images in total
# extracting feature from image No. 37 , 250 images in total
# extracting feature from image No. 38 , 250 images in total
# extracting feature from image No. 39 , 250 images in total
# extracting feature from image No. 40 , 250 images in total
# extracting feature from image No. 41 , 250 images in total
# extracting feature from image No. 42 , 250 images in total
# extracting feature from image No. 43 , 250 images in total
# extracting feature from image No. 44 , 250 images in total
# extracting feature from image No. 45 , 250 images in total
# extracting feature from image No. 46 , 250 images in total
# extracting feature from image No. 47 , 250 images in total
# extracting feature from image No. 48 , 250 images in total
# extracting feature from image No. 49 , 250 images in total
# extracting feature from image No. 50 , 250 images in total
# extracting feature from image No. 51 , 250 images in total
# extracting feature from image No. 52 , 250 images in total
# extracting feature from image No. 53 , 250 images in total
# extracting feature from image No. 54 , 250 images in total
# extracting feature from image No. 55 , 250 images in total
# extracting feature from image No. 56 , 250 images in total
# extracting feature from image No. 57 , 250 images in total
# extracting feature from image No. 58 , 250 images in total
# extracting feature from image No. 59 , 250 images in total
# extracting feature from image No. 60 , 250 images in total
# extracting feature from image No. 61 , 250 images in total
# extracting feature from image No. 62 , 250 images in total
# extracting feature from image No. 63 , 250 images in total
# extracting feature from image No. 64 , 250 images in total
# extracting feature from image No. 65 , 250 images in total
# extracting feature from image No. 66 , 250 images in total
# extracting feature from image No. 67 , 250 images in total
# extracting feature from image No. 68 , 250 images in total
# extracting feature from image No. 69 , 250 images in total
# extracting feature from image No. 70 , 250 images in total
# extracting feature from image No. 71 , 250 images in total
# extracting feature from image No. 72 , 250 images in total
# extracting feature from image No. 73 , 250 images in total
# extracting feature from image No. 74 , 250 images in total
# extracting feature from image No. 75 , 250 images in total
# extracting feature from image No. 76 , 250 images in total
# extracting feature from image No. 77 , 250 images in total
# extracting feature from image No. 78 , 250 images in total
# extracting feature from image No. 79 , 250 images in total
# extracting feature from image No. 80 , 250 images in total
# extracting feature from image No. 81 , 250 images in total
# extracting feature from image No. 82 , 250 images in total
# extracting feature from image No. 83 , 250 images in total
# extracting feature from image No. 84 , 250 images in total
# extracting feature from image No. 85 , 250 images in total
# extracting feature from image No. 86 , 250 images in total
# extracting feature from image No. 87 , 250 images in total
# extracting feature from image No. 88 , 250 images in total
# extracting feature from image No. 89 , 250 images in total
# extracting feature from image No. 90 , 250 images in total
# extracting feature from image No. 91 , 250 images in total
# extracting feature from image No. 92 , 250 images in total
# extracting feature from image No. 93 , 250 images in total
# extracting feature from image No. 94 , 250 images in total
# extracting feature from image No. 95 , 250 images in total
# extracting feature from image No. 96 , 250 images in total
# extracting feature from image No. 97 , 250 images in total
# extracting feature from image No. 98 , 250 images in total
# extracting feature from image No. 99 , 250 images in total
# extracting feature from image No. 100 , 250 images in total
# extracting feature from image No. 101 , 250 images in total
# extracting feature from image No. 102 , 250 images in total
# extracting feature from image No. 103 , 250 images in total
# extracting feature from image No. 104 , 250 images in total
# extracting feature from image No. 105 , 250 images in total
# extracting feature from image No. 106 , 250 images in total
# extracting feature from image No. 107 , 250 images in total
# extracting feature from image No. 108 , 250 images in total
# extracting feature from image No. 109 , 250 images in total
# extracting feature from image No. 110 , 250 images in total
# extracting feature from image No. 111 , 250 images in total
# extracting feature from image No. 112 , 250 images in total
# extracting feature from image No. 113 , 250 images in total
# extracting feature from image No. 114 , 250 images in total
# extracting feature from image No. 115 , 250 images in total
# extracting feature from image No. 116 , 250 images in total
# extracting feature from image No. 117 , 250 images in total
# extracting feature from image No. 118 , 250 images in total
# extracting feature from image No. 119 , 250 images in total
# extracting feature from image No. 120 , 250 images in total
# extracting feature from image No. 121 , 250 images in total
# extracting feature from image No. 122 , 250 images in total
# extracting feature from image No. 123 , 250 images in total
# extracting feature from image No. 124 , 250 images in total
# extracting feature from image No. 125 , 250 images in total
# extracting feature from image No. 126 , 250 images in total
# extracting feature from image No. 127 , 250 images in total
# extracting feature from image No. 128 , 250 images in total
# extracting feature from image No. 129 , 250 images in total
# extracting feature from image No. 130 , 250 images in total
# extracting feature from image No. 131 , 250 images in total
# extracting feature from image No. 132 , 250 images in total
# extracting feature from image No. 133 , 250 images in total
# extracting feature from image No. 134 , 250 images in total
# extracting feature from image No. 135 , 250 images in total
# extracting feature from image No. 136 , 250 images in total
# extracting feature from image No. 137 , 250 images in total
# extracting feature from image No. 138 , 250 images in total
# extracting feature from image No. 139 , 250 images in total
# extracting feature from image No. 140 , 250 images in total
# extracting feature from image No. 141 , 250 images in total
# extracting feature from image No. 142 , 250 images in total
# extracting feature from image No. 143 , 250 images in total
# extracting feature from image No. 144 , 250 images in total
# extracting feature from image No. 145 , 250 images in total
# extracting feature from image No. 146 , 250 images in total
# extracting feature from image No. 147 , 250 images in total
# extracting feature from image No. 148 , 250 images in total
# extracting feature from image No. 149 , 250 images in total
# extracting feature from image No. 150 , 250 images in total
# extracting feature from image No. 151 , 250 images in total
# extracting feature from image No. 152 , 250 images in total
# extracting feature from image No. 153 , 250 images in total
# extracting feature from image No. 154 , 250 images in total
# extracting feature from image No. 155 , 250 images in total
# extracting feature from image No. 156 , 250 images in total
# extracting feature from image No. 157 , 250 images in total
# extracting feature from image No. 158 , 250 images in total
# extracting feature from image No. 159 , 250 images in total
# extracting feature from image No. 160 , 250 images in total
# extracting feature from image No. 161 , 250 images in total
# extracting feature from image No. 162 , 250 images in total
# extracting feature from image No. 163 , 250 images in total
# extracting feature from image No. 164 , 250 images in total
# extracting feature from image No. 165 , 250 images in total
# extracting feature from image No. 166 , 250 images in total
# extracting feature from image No. 167 , 250 images in total
# extracting feature from image No. 168 , 250 images in total
# extracting feature from image No. 169 , 250 images in total
# extracting feature from image No. 170 , 250 images in total
# extracting feature from image No. 171 , 250 images in total
# extracting feature from image No. 172 , 250 images in total
# extracting feature from image No. 173 , 250 images in total
# extracting feature from image No. 174 , 250 images in total
# extracting feature from image No. 175 , 250 images in total
# extracting feature from image No. 176 , 250 images in total
# extracting feature from image No. 177 , 250 images in total
# extracting feature from image No. 178 , 250 images in total
# extracting feature from image No. 179 , 250 images in total
# extracting feature from image No. 180 , 250 images in total
# extracting feature from image No. 181 , 250 images in total
# extracting feature from image No. 182 , 250 images in total
# extracting feature from image No. 183 , 250 images in total
# extracting feature from image No. 184 , 250 images in total
# extracting feature from image No. 185 , 250 images in total
# extracting feature from image No. 186 , 250 images in total
# extracting feature from image No. 187 , 250 images in total
# extracting feature from image No. 188 , 250 images in total
# extracting feature from image No. 189 , 250 images in total
# extracting feature from image No. 190 , 250 images in total
# extracting feature from image No. 191 , 250 images in total
# extracting feature from image No. 192 , 250 images in total
# extracting feature from image No. 193 , 250 images in total
# extracting feature from image No. 194 , 250 images in total
# extracting feature from image No. 195 , 250 images in total
# extracting feature from image No. 196 , 250 images in total
# extracting feature from image No. 197 , 250 images in total
# extracting feature from image No. 198 , 250 images in total
# extracting feature from image No. 199 , 250 images in total
# extracting feature from image No. 200 , 250 images in total
# extracting feature from image No. 201 , 250 images in total
# extracting feature from image No. 202 , 250 images in total
# extracting feature from image No. 203 , 250 images in total
# extracting feature from image No. 204 , 250 images in total
# extracting feature from image No. 205 , 250 images in total
# extracting feature from image No. 206 , 250 images in total
# extracting feature from image No. 207 , 250 images in total
# extracting feature from image No. 208 , 250 images in total
# extracting feature from image No. 209 , 250 images in total
# extracting feature from image No. 210 , 250 images in total
# extracting feature from image No. 211 , 250 images in total
# extracting feature from image No. 212 , 250 images in total
# extracting feature from image No. 213 , 250 images in total
# extracting feature from image No. 214 , 250 images in total
# extracting feature from image No. 215 , 250 images in total
# extracting feature from image No. 216 , 250 images in total
# extracting feature from image No. 217 , 250 images in total
# extracting feature from image No. 218 , 250 images in total
# extracting feature from image No. 219 , 250 images in total
# extracting feature from image No. 220 , 250 images in total
# extracting feature from image No. 221 , 250 images in total
# extracting feature from image No. 222 , 250 images in total
# extracting feature from image No. 223 , 250 images in total
# extracting feature from image No. 224 , 250 images in total
# extracting feature from image No. 225 , 250 images in total
# extracting feature from image No. 226 , 250 images in total
# extracting feature from image No. 227 , 250 images in total
# extracting feature from image No. 228 , 250 images in total
# extracting feature from image No. 229 , 250 images in total
# extracting feature from image No. 230 , 250 images in total
# extracting feature from image No. 231 , 250 images in total
# extracting feature from image No. 232 , 250 images in total
# extracting feature from image No. 233 , 250 images in total
# extracting feature from image No. 234 , 250 images in total
# extracting feature from image No. 235 , 250 images in total
# extracting feature from image No. 236 , 250 images in total
# extracting feature from image No. 237 , 250 images in total
# extracting feature from image No. 238 , 250 images in total
# extracting feature from image No. 239 , 250 images in total
# extracting feature from image No. 240 , 250 images in total
# extracting feature from image No. 241 , 250 images in total
# extracting feature from image No. 242 , 250 images in total
# extracting feature from image No. 243 , 250 images in total
# extracting feature from image No. 244 , 250 images in total
# extracting feature from image No. 245 , 250 images in total
# extracting feature from image No. 246 , 250 images in total
# extracting feature from image No. 247 , 250 images in total
# extracting feature from image No. 248 , 250 images in total
# extracting feature from image No. 249 , 250 images in total
# extracting feature from image No. 250 , 250 images in total

# %%
# directory for storing extracted features


print("--------------------------------------------------")
print("      writing feature extraction results ...")
print("--------------------------------------------------")

output = 'featureCNN-vgg19-3.h5'
h5f = h5py.File(output, 'w')
h5f.create_dataset('feats', data = feats)
h5f.create_dataset('names', data = np.string_(names))
h5f.close()
end = time.time()
print("Cost time: ",end-start," (s)")
# Out:
# --------------------------------------------------
#       writing feature extraction results ...
# --------------------------------------------------
# Cost time:  88.36284375190735  (s)

# %%
model = FeatureExtractor()

# %%
import numpy as np
import h5py
import os
import  matplotlib
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

h5f = h5py.File('featureCNN-vgg19-3.h5','r')

feats = h5f['feats'][:]
# print(feats)

imgNames = h5f['names'][:]
h5f.close()

print("--------------------------------------------------")
print("               searching starts")
print("--------------------------------------------------")

# read and show query image
queryDir = 'Citrabatik_dataset/test/B1_1.jpg' 
queryImg = mpimg.imread(queryDir)
plt.title("Query Image")
plt.imshow(queryImg)
plt.show()

# init InceptionResNet_V2 model
#model = InceptionResNet_V2()

# extract query image's feature, compute simlarity score and sort
queryVec = model.extract_features(queryDir)
scores = np.dot(queryVec, feats.T)
rank_ID = np.argsort(scores)[::-1]
rank_score = scores[rank_ID]


# number of top retrieved images to show
maxres = 5
imlist = [str(imgNames[index]).split("'")[1].split("_")[0] for i,index in enumerate(rank_ID[0:maxres])]
print("top %d images in order are: " %maxres, imlist)
# Out:
# --------------------------------------------------
#                searching starts
# --------------------------------------------------
# top 5 images in order are:  ['B1', 'B1', 'B1', 'B1', 'B1']

# %%
plt.style.use("ggplot")
plt.title("Visualisasi Query sebelum di Sorting")
x =rank_ID
y=scores
plt.xlabel("Rank_ID")
plt.ylabel("Score")
plt.scatter(x, y)
plt.show()

# %%
plt.style.use("ggplot")
plt.title("Visualisasi Query setelah di Sorting")
x =rank_ID
y=rank_score
plt.xlabel("Rank_ID")
plt.ylabel("Score")
plt.scatter(x, y)
plt.show()

# %%
kelas_batik = []
presisi_kelas = []
path_test = 'Citrabatik_dataset/test/' 
test_list = get_imlist(path_test)
for img_path in test_list:
    queryDir = img_path
    img_name = os.path.split(img_path)[1]
    img_name = img_name.split('_')[0]
    kelas_batik.append(img_name)
    
    queryVec = model.extract_features(queryDir)
    scores = np.dot(queryVec, feats.T)
    rank_ID = np.argsort(scores)[::-1]
    rank_score = scores[rank_ID]

    # number of top retrieved images to show
    maxres = 5
    imlist = [str(imgNames[index]).split("'")[1].split("_")[0] for i,index in enumerate(rank_ID[0:maxres])]
    count = 0
    for list_kelas in imlist:
        if img_name in list_kelas:
            count += 1
    presisi = count / maxres
    presisi_kelas.append(presisi)
    print("top %d images in order are: " %maxres, imlist)
# Out:
# top 5 images in order are:  ['B10', 'B10', 'B10', 'B23', 'B10']
# top 5 images in order are:  ['B11', 'B11', 'B11', 'B11', 'B11']
# top 5 images in order are:  ['B12', 'B12', 'B12', 'B12', 'B12']
# top 5 images in order are:  ['B13', 'B13', 'B13', 'B13', 'B13']
# top 5 images in order are:  ['B14', 'B14', 'B14', 'B14', 'B14']
# top 5 images in order are:  ['B15', 'B15', 'B15', 'B15', 'B23']
# top 5 images in order are:  ['B16', 'B16', 'B11', 'B11', 'B11']
# top 5 images in order are:  ['B17', 'B17', 'B17', 'B17', 'B17']
# top 5 images in order are:  ['B18', 'B18', 'B18', 'B18', 'B18']
# top 5 images in order are:  ['B19', 'B19', 'B19', 'B19', 'B19']
# top 5 images in order are:  ['B1', 'B1', 'B1', 'B1', 'B1']
# top 5 images in order are:  ['B20', 'B20', 'B20', 'B20', 'B20']
# top 5 images in order are:  ['B21', 'B21', 'B21', 'B21', 'B21']
# top 5 images in order are:  ['B22', 'B22', 'B22', 'B22', 'B22']
# top 5 images in order are:  ['B23', 'B23', 'B23', 'B23', 'B23']
# top 5 images in order are:  ['B24', 'B24', 'B24', 'B24', 'B24']
# top 5 images in order are:  ['B25', 'B25', 'B25', 'B25', 'B25']
# top 5 images in order are:  ['B26', 'B26', 'B26', 'B26', 'B26']
# top 5 images in order are:  ['B27', 'B27', 'B27', 'B27', 'B27']
# top 5 images in order are:  ['B28', 'B28', 'B27', 'B27', 'B27']
# top 5 images in order are:  ['B29', 'B29', 'B29', 'B29', 'B48']
# top 5 images in order are:  ['B2', 'B2', 'B2', 'B2', 'B2']
# top 5 images in order are:  ['B30', 'B30', 'B30', 'B30', 'B30']
# top 5 images in order are:  ['B31', 'B31', 'B31', 'B31', 'B31']
# top 5 images in order are:  ['B32', 'B32', 'B32', 'B32', 'B32']
# top 5 images in order are:  ['B33', 'B33', 'B33', 'B33', 'B12']
# top 5 images in order are:  ['B49', 'B34', 'B34', 'B34', 'B49']
# top 5 images in order are:  ['B35', 'B35', 'B35', 'B35', 'B35']
# top 5 images in order are:  ['B36', 'B36', 'B36', 'B36', 'B36']
# top 5 images in order are:  ['B37', 'B37', 'B37', 'B37', 'B37']
# top 5 images in order are:  ['B38', 'B38', 'B38', 'B38', 'B38']
# top 5 images in order are:  ['B39', 'B39', 'B39', 'B39', 'B39']
# top 5 images in order are:  ['B3', 'B3', 'B3', 'B3', 'B3']
# top 5 images in order are:  ['B40', 'B40', 'B40', 'B40', 'B40']
# top 5 images in order are:  ['B41', 'B41', 'B41', 'B41', 'B41']
# top 5 images in order are:  ['B42', 'B42', 'B42', 'B42', 'B42']
# top 5 images in order are:  ['B43', 'B43', 'B43', 'B43', 'B43']
# top 5 images in order are:  ['B44', 'B44', 'B44', 'B44', 'B44']
# top 5 images in order are:  ['B45', 'B45', 'B45', 'B45', 'B45']
# top 5 images in order are:  ['B46', 'B46', 'B46', 'B46', 'B46']
# top 5 images in order are:  ['B47', 'B47', 'B47', 'B44', 'B11']
# top 5 images in order are:  ['B48', 'B48', 'B48', 'B48', 'B48']
# top 5 images in order are:  ['B49', 'B49', 'B49', 'B49', 'B49']
# top 5 images in order are:  ['B4', 'B4', 'B4', 'B4', 'B4']
# top 5 images in order are:  ['B50', 'B50', 'B50', 'B50', 'B50']
# top 5 images in order are:  ['B5', 'B5', 'B5', 'B5', 'B5']
# top 5 images in order are:  ['B6', 'B6', 'B6', 'B6', 'B6']
# top 5 images in order are:  ['B7', 'B7', 'B7', 'B7', 'B7']
# top 5 images in order are:  ['B8', 'B8', 'B8', 'B8', 'B8']
# top 5 images in order are:  ['B9', 'B9', 'B9', 'B9', 'B9']

# %%
import pandas as pd
df = pd.DataFrame(list(zip(kelas_batik, presisi_kelas)),
               columns =['Kelas', 'precision'])

# %%
df
# Out:
#    Kelas  precision
# 0    B10        0.8
# 1    B11        1.0
# 2    B12        1.0
# 3    B13        1.0
# 4    B14        1.0
# 5    B15        0.8
# 6    B16        0.4
# 7    B17        1.0
# 8    B18        1.0
# 9    B19        1.0
# 10    B1        1.0
# 11   B20        1.0
# 12   B21        1.0
# 13   B22        1.0
# 14   B23        1.0
# 15   B24        1.0
# 16   B25        1.0
# 17   B26        1.0
# 18   B27        1.0
# 19   B28        0.4
# 20   B29        0.8
# 21    B2        1.0
# 22   B30        1.0
# 23   B31        1.0
# 24   B32        1.0
# 25   B33        0.8
# 26   B34        0.6
# 27   B35        1.0
# 28   B36        1.0
# 29   B37        1.0
# 30   B38        1.0
# 31   B39        1.0
# 32    B3        1.0
# 33   B40        1.0
# 34   B41        1.0
# 35   B42        1.0
# 36   B43        1.0
# 37   B44        1.0
# 38   B45        1.0
# 39   B46        1.0
# 40   B47        0.6
# 41   B48        1.0
# 42   B49        1.0
# 43    B4        1.0
# 44   B50        1.0
# 45    B5        1.0
# 46    B6        1.0
# 47    B7        1.0
# 48    B8        1.0
# 49    B9        1.0

# %%
precision = df['precision'].sum()/len(df['precision'])
precision
# Out:
# 0.9440000000000001

# %%
h5f = h5py.File('featureCNN-vgg19-3.h5','r')

feats = h5f['feats'][:]
# print(feats)

imgNames = h5f['names'][:]
h5f.close()

# %%
queryDir = 'Citrabatik_dataset/test/B1_1.jpg'
queryImg = mpimg.imread(queryDir)
plt.title("Query Image")
plt.imshow(queryImg)
plt.show()

queryVec = model.extract_features(queryDir)
scores = np.dot(queryVec, feats.T)
rank_ID = np.argsort(scores)[::-1]
rank_score = scores[rank_ID]


# number of top retrieved images to show
maxres = 5
imlist = [imgNames[index] for i,index in enumerate(rank_ID[0:maxres])]
print("top %d images in order are: " %maxres, imlist)
# Out:
# top 5 images in order are:  [b'B39_5.jpg', b'B39_6.jpg', b'B39_3.jpg', b'B39_4.jpg', b'B36_4.jpg']

# %%
# show top #maxres retrieved result one by one
for i,im in enumerate(imlist):
    image = mpimg.imread(path+"/"+str(im, 'utf-8'))
    plt.title("search output %d" %(i+1))
    plt.imshow(image)
    plt.show()
